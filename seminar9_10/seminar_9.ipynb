# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Задача №57.
#
# 1. Прочесть с помощью pandas файл california_housing_test.csv, который находится в папке sample_data
# 2. Посмотреть сколько в нем строк и столбцов
# 3. Определить какой тип данных имеют столбцы

# %%
df = pd.read_csv('/content/sample_data/california_housing_train.csv')
df.sample(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 294      -116.79     33.99                16.0        319.0            68.0
# 5464     -118.16     33.97                32.0       1347.0           434.0
# 12454    -121.60     39.79                18.0       2672.0           533.0
# 8168     -118.43     33.99                35.0       2243.0           495.0
# 7710     -118.38     34.10                39.0       3798.0           586.0
#
#        population  households  median_income  median_house_value
# 294         212.0        67.0         1.4688             90000.0
# 5464       1756.0       438.0         1.9464            190600.0
# 12454      1151.0       532.0         2.5670            102900.0
# 8168       1135.0       465.0         4.3281            324000.0
# 7710        975.0       525.0         9.3092            500001.0

# %%
df.shape
# Out:
# (17000, 9)

# %%
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %% [markdown]
# ## Задача №59.
# 1. Проверить есть ли в файле пустые значения
# 2. Показать median_house_value где median_income < 2
# 3. Показать данные в первых 2 столбцах
# 4. Выбрать данные где housing_median_age < 20 и median_house_value > 70000

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df.sample()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16991    -124.23     41.75                11.0       3159.0           616.0
#
#        population  households  median_income  median_house_value
# 16991      1343.0       479.0         2.4805             73200.0

# %%
df[df['median_income']<2]['median_house_value']
# Out:
# 0        66900.0
# 1        80100.0
# 2        85700.0
# 4        65500.0
# 7        48500.0
#           ...
# 16984    70000.0
# 16989    58100.0
# 16990    78300.0
# 16994    76100.0
# 16998    85800.0
# Name: median_house_value, Length: 2005, dtype: float64

# %%
df[df.median_income<2].median_house_value
# Out:
# 0        66900.0
# 1        80100.0
# 2        85700.0
# 4        65500.0
# 7        48500.0
#           ...
# 16984    70000.0
# 16989    58100.0
# 16990    78300.0
# 16994    76100.0
# 16998    85800.0
# Name: median_house_value, Length: 2005, dtype: float64

# %%
df.loc[df['median_income']<2,'median_house_value']
# Out:
# 0        66900.0
# 1        80100.0
# 2        85700.0
# 4        65500.0
# 7        48500.0
#           ...
# 16984    70000.0
# 16989    58100.0
# 16990    78300.0
# 16994    76100.0
# 16998    85800.0
# Name: median_house_value, Length: 2005, dtype: float64

# %%
df[['longitude','latitude']]
# Out:
#        longitude  latitude
# 0        -114.31     34.19
# 1        -114.47     34.40
# 2        -114.56     33.69
# 3        -114.57     33.64
# 4        -114.57     33.57
# ...          ...       ...
# 16995    -124.26     40.58
# 16996    -124.27     40.69
# 16997    -124.30     41.84
# 16998    -124.30     41.80
# 16999    -124.35     40.54
#
# [17000 rows x 2 columns]

# %%
df.columns[:2]
# Out:
# Index(['longitude', 'latitude'], dtype='object')

# %%
df[df.columns[:2]]
# Out:
#        longitude  latitude
# 0        -114.31     34.19
# 1        -114.47     34.40
# 2        -114.56     33.69
# 3        -114.57     33.64
# 4        -114.57     33.57
# ...          ...       ...
# 16995    -124.26     40.58
# 16996    -124.27     40.69
# 16997    -124.30     41.84
# 16998    -124.30     41.80
# 16999    -124.35     40.54
#
# [17000 rows x 2 columns]

# %%
df.loc[:5,['longitude','latitude']]
# Out:
#    longitude  latitude
# 0    -114.31     34.19
# 1    -114.47     34.40
# 2    -114.56     33.69
# 3    -114.57     33.64
# 4    -114.57     33.57
# 5    -114.58     33.63

# %%
df.iloc[:5,:2]
# Out:
#    longitude  latitude
# 0    -114.31     34.19
# 1    -114.47     34.40
# 2    -114.56     33.69
# 3    -114.57     33.64
# 4    -114.57     33.57

# %%
df.iloc[:5,:2]
# Out:
#    longitude  latitude
# 0    -114.31     34.19
# 1    -114.47     34.40
# 2    -114.56     33.69
# 3    -114.57     33.64
# 4    -114.57     33.57

# %%
df[(df['housing_median_age']<20) & (df['median_house_value']>70000)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 10       -114.60     33.62                16.0       3741.0           801.0
# 23       -114.98     33.82                15.0        644.0           129.0
# ...          ...       ...                 ...          ...             ...
# 16976    -124.17     40.75                13.0       2171.0           339.0
# 16983    -124.19     41.78                15.0       3140.0           714.0
# 16991    -124.23     41.75                11.0       3159.0           616.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
#
# ...

# %% [markdown]
# ##Задача №61.
# 1. Определить какое максимальное и минимальное значение median_house_value
#
# 2. Показать максимальное median_house_value, где median_income = 3.1250
#
# 3. Узнать какая максимальная population в зоне минимального значения median_house_value

# %%
df['median_house_value'].min(),df['median_house_value'].max()
# Out:
# (14999.0, 500001.0)

# %%
df[df['median_income'] == 3.125]['median_house_value'].max()
# Out:
# 380400.0

# %%
df[df['median_house_value']==df['median_house_value'].min()]['population'].max()
# Out:
# 628.0

# %% [markdown]
# Дан файл california_housing_train.csv. Определить среднюю стоимость дома , где количество людей от 0 до 500 (population) и сохранить ее в переменную avg.
# Используйте модуль pandas.

# %%
df[(df['population'] <= 100) & (df['population'] == 100)][['total_rooms', 'population']]
# Out:
#        total_rooms  population
# 7650         138.0       100.0
# 15650        215.0       100.0

# %%
df[df['population'] == df['population'].min()]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8232    -118.44     34.04                16.0         18.0             6.0
#
#       population  households  median_income  median_house_value
# 8232         3.0         4.0          0.536            350000.0

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
import seaborn as sns

# %%
sns.scatterplot(data=df, x = 'longitude', y = 'latitude')
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
sns.scatterplot(data=df, x = 'households', y = 'population', hue = 'total_rooms')
# Out:
# <Axes: xlabel='households', ylabel='population'>

# %%
sns.scatterplot(data=df, x = 'households', y = 'population', hue = 'total_rooms', size = 10)
# Out:
# <Axes: xlabel='households', ylabel='population'>

# %%
cols = ['population', 'housing_median_age', 'median_income', 'median_house_value']
g = sns.PairGrid(df[cols])
g.map(sns.scatterplot)

# %%
sns.relplot(data=df, x = 'latitude', y = 'median_house_value', kind = 'line')

# %%
sns.relplot(data=df, x = 'longitude', y = 'median_house_value', kind = 'line')

# %%
sns.relplot(data=df, x = 'latitude', y = 'longitude', hue = 'median_house_value')

# %%
sns.histplot(data=df, x = 'median_income')
# Out:
# <Axes: xlabel='median_income', ylabel='Count'>

# %%
sns.histplot(data=df, x = 'housing_median_age')
# Out:
# <Axes: xlabel='housing_median_age', ylabel='Count'>

# %%
sns.histplot(data=df[df['housing_median_age'] > 50], x = 'median_income')
# Out:
# <Axes: xlabel='median_income', ylabel='Count'>

# %%
df.loc[df['housing_median_age'] <= 20, 'housing_median_age']
# Out:
# 0        15.0
# 1        19.0
# 2        17.0
# 3        14.0
# 4        20.0
#          ...
# 16987    17.0
# 16988    20.0
# 16991    11.0
# 16997    17.0
# 16998    19.0
# Name: housing_median_age, Length: 5209, dtype: float64

# %%
df.loc[df['housing_median_age'] <= 20, 'age_group'] = 'Молодые'
df.loc[(df['housing_median_age'] > 20) & (df['housing_median_age'] <= 50), 'age_group'] = 'Средний возраст'
df.loc[df['housing_median_age'] > 50, 'age_group'] = 'Пожилые'

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'age_group'],
#       dtype='object')

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value age_group
# 0      1015.0       472.0         1.4936             66900.0   Молодые
# 1      1129.0       463.0         1.8200             80100.0   Молодые
# 2       333.0       117.0         1.6509             85700.0   Молодые
# 3       515.0       226.0         3.1917             73400.0   Молодые
# 4       624.0       262.0         1.9250             65500.0   Молодые

# %%
df.groupby('age_group')['median_income'].mean().plot(kind = 'bar')
# Out:
# <Axes: xlabel='age_group'>

# %%
df.loc[df['median_income'] > 6, 'income_group'] = 'rich'
df.loc[df['median_income'] < 6, 'income_group'] = 'everyone_else'

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value age_group  \
# 0      1015.0       472.0         1.4936             66900.0   Молодые
# 1      1129.0       463.0         1.8200             80100.0   Молодые
# 2       333.0       117.0         1.6509             85700.0   Молодые
# 3       515.0       226.0         3.1917             73400.0   Молодые
# 4       624.0       262.0         1.9250             65500.0   Молодые
#
#     income_group
# 0  everyone_else
# 1  everyone_else
# 2  everyone_else
# 3  everyone_else
# ...

# %%
sns.histplot(data = df, x = 'median_house_value', hue = 'income_group')
# Out:
# <Axes: xlabel='median_house_value', ylabel='Count'>

# %% [markdown]
# # Seminar 10

# %% [markdown]
# ## Задача №63.
# Решение в группах
# 1. Изобразите отношение households к population с
# помощью точечного графика
# 2. Визуализировать longitude по отношения к
# median_house_value, используя линейный график
# 3. Представить гистограмму по housing_median_age
# 4. Изобразить гистограмму по median_house_value с
# оттенком housing_median_age

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
sns.set(style='darkgrid', context='paper', palette='summer')
sns.scatterplot(data=df, x = 'households', y = 'population')
# Out:
# <Axes: xlabel='households', ylabel='population'>

# %%
sns.set(style='darkgrid', context='paper', palette='gray')
sns.relplot(data=df, x = 'longitude', y = 'median_house_value', kind = 'line')

# %%
sns.histplot(data = df, x = 'housing_median_age')
# Out:
# <Axes: xlabel='housing_median_age', ylabel='Count'>

# %%
sns.displot(data = df, x = 'median_house_value', hue = 'housing_median_age')

# %% [markdown]
# ## Задача №65.
# Решение в группах
# Написать EDA для датасета про пингвинов
# Необходимо:
# -  Использовать 2-3 точечных графика
# -  Применить доп измерение в точечных графиках, используя
# аргументы hue, size, stile
# -  Использовать PairGrid с типом графика на ваш выбор
# -  Изобразить Heatmap
# -  Использовать 2-3 гистограммы
#
# Чтобы подключить датасет с
# пингвинами, воспользуйтесь данным
# скриптом:
# penguins = sns.load_dataset("penguins")
# penguins.head()

# %%
penguins = sns.load_dataset('penguins')

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
sns.scatterplot(data=penguins, x = 'bill_length_mm', y = 'bill_depth_mm', hue='sex', palette='rainbow', size='species')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data=penguins, x = 'flipper_length_mm', y = 'body_mass_g', hue='sex', palette='rainbow', size='body_mass_g')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.set(palette='rainbow', context='paper')
cols = ['species', 'sex', 'flipper_length_mm', 'body_mass_g', 'island', 'bill_length_mm', 'bill_depth_mm']
g = sns.PairGrid(penguins[cols], hue='species')
g.map(sns.scatterplot)

# %%
sns.histplot(data = penguins, x = 'island', hue='species', palette='inferno')
# Out:
# <Axes: xlabel='island', ylabel='Count'>

# %%
sns.histplot(data = penguins, x = 'body_mass_g', hue='sex', palette='inferno')
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Count'>

# %%
import numpy as np
lst1 = list(penguins['bill_length_mm'])[:324]
#lst2 = list(penguins['bill_length_mm'])
#len(lst1)
lst1 = np.array(lst1).reshape((18,18))
#print(lst1)
sns.heatmap(data = lst1, annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ##Задача №67.
# Решение в группах
# 1. Создать новый столбец в таблице с
# пингвинами, который будет отвечать за
# показатель длины клюва пингвина.
# - high - длинный(от 42)
# - middle - средний(от 35 до 42)
# - low - маленький(до 35)
#
# Чтобы подключить датасет с
# пингвинами, воспользуйтесь данным
# скриптом:
# penguins = sns.load_dataset("penguins")
# penguins.head()

# %%
penguins.loc[penguins['bill_length_mm'] >= 42, 'height_group'] = 'high'
penguins.loc[(penguins['bill_length_mm'] < 42) & (penguins['bill_length_mm'] >= 35), 'height_group'] = 'middle'
penguins.loc[penguins['bill_length_mm'] < 35, 'height_group'] = 'low'
#df.loc[df['median_income'] > 6, 'income_group'] = 'rich'

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex height_group
# 0         3750.0    Male       middle
# ...

# %%
sns.barplot(data = penguins, x='height_group', hue='sex', palette='inferno')
# Out:
# <Axes: xlabel='height_group'>

# %%
sns.histplot(data=penguins, x='bill_length_mm', hue='height_group', multiple='stack')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
import random
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head()
# Out:
#   whoAmI
# 0  human
# 1  human
# 2  robot
# 3  robot
# 4  human

# %%
data.loc[data['whoAmI'] == 'robot'] = '1'
data.loc[data['whoAmI'] == 'human'] = '0'
data.head()
# Out:
#   whoAmI
# 0      0
# 1      0
# 2      1
# 3      1
# 4      0

# %% [markdown]
# ## Задача 44:
# В ячейке ниже представлен код генерирующий DataFrame, которая состоит всего
# из 1 столбца. Ваша задача перевести его в one hot вид. Сможете ли вы это сделать без
# - get_dummies?
#
# - import random
# - lst = ['robot'] * 10
# - lst += ['human'] * 10
# - random.shuffle(lst)
# - data = pd.DataFrame({'whoAmI':lst})
# - data.head()
